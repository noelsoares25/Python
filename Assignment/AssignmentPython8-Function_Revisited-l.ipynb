# %%
#Q1
num=int(input('enter the number: '))
f=lambda x:pow(x,2)
f1=lambda x: 1/x
f2=lambda x: x*(-1)
print(f(num))
print(f1(num))
print(f2(num))
# Out:
# enter the number: 2
# 4
# 0.5
# -2

# %%
#Q2
from functools import reduce
a=[10,20,2,4,45,54,13,120]
f1=reduce(lambda x,y:x if x>y else y,a)
print(f1)
# Out:
# 120

# %%
#Q3
def map_multiple1(f,a):
    for i in f:
        print(i)
f=lambda x:pow(x,2)
a=[1,2,4]

# %% [markdown]
# #### Q4
# 50

# %% [markdown]
# #### Q5
# [1.0, 0.5, 0.25, 0.125]

# %%
#Q6
s=input('enter the string: ')
t=tuple(s)
l=list(t)
f=filter(lambda x,y: x if(isinstance(x,int)) ,l)
print(f)
# Out:
#   File "<ipython-input-30-6d71deffad46>", line 5
#     f=filter(lambda x,y: x if(isinstance(x,int)) else continue,l)
#                                                              ^
# SyntaxError: invalid syntax

# %%
#Q6
integer=set('1234567890')
s=input('enter the string: ')
t=tuple(s)
l=list(t)
#print(type(l[4]))
for x in l:
    if(x in integer):
        z=int(x)
        c[x]=z
print(c)
# Out:
# enter the string: noel4
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-81-2e08bab30e7d> in <module>
#       8     if(x in integer):
#       9         z=int(x)
# ---> 10         c[x]=z
#      11 print(c)
#      12
#
# TypeError: 'int' object does not support item assignment

# %%
z='234'
print(type(z))
c=int(z)
print(type(c))
# Out:
# <class 'str'>
# <class 'int'>
